# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv('BX-Books.csv', sep='\";\"', names=['ISBN', 'Book-Title' ,'Book-Author','Year-Of-Publication', 'Publisher', 'Image-Url-S', 'Image-Url-M', 'Image-Url-L'], encoding='latin-1', skiprows=1)
# Out:
# /tmp/ipykernel_184/2493138330.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data1 = pd.read_csv('BX-Books.csv', sep='\";\"', names=['ISBN', 'Book-Title' ,'Book-Author','Year-Of-Publication', 'Publisher', 'Image-Url-S', 'Image-Url-M', 'Image-Url-L'], encoding='latin-1', skiprows=1)

# %%
data1.head()
# Out:
#           ISBN                                         Book-Title  \
# 0  "0195153448                                Classical Mythology
# 1  "0002005018                                       Clara Callan
# 2  "0060973129                               Decision in Normandy
# 3  "0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  "0393045218                             The Mummies of Urumchi
#
#             Book-Author  Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                 2002     Oxford University Press
# 1  Richard Bruce Wright                 2001       HarperFlamingo Canada
# 2          Carlo D'Este                 1991             HarperPerennial
# 3      Gina Bari Kolata                 1999        Farrar Straus Giroux
# 4       E. J. W. Barber                 1999  W. W. Norton &amp; Company
#
#                                          Image-Url-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
data1.dtypes
# Out:
# ISBN                   object
# Book-Title             object
# Book-Author            object
# Year-Of-Publication     int64
# Publisher              object
# Image-Url-S            object
# Image-Url-M            object
# Image-Url-L            object
# dtype: object

# %%
data1_colsrem = data1.drop(columns=['Image-Url-S', 'Image-Url-M','Image-Url-L'])

# %%
data1_colsrem.head()
# Out:
#           ISBN                                         Book-Title  \
# 0  "0195153448                                Classical Mythology
# 1  "0002005018                                       Clara Callan
# 2  "0060973129                               Decision in Normandy
# 3  "0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  "0393045218                             The Mummies of Urumchi
#
#             Book-Author  Year-Of-Publication                   Publisher
# 0    Mark P. O. Morford                 2002     Oxford University Press
# 1  Richard Bruce Wright                 2001       HarperFlamingo Canada
# 2          Carlo D'Este                 1991             HarperPerennial
# 3      Gina Bari Kolata                 1999        Farrar Straus Giroux
# 4       E. J. W. Barber                 1999  W. W. Norton &amp; Company

# %%
newcol_data1 = {
    "Book-Title": "Book_Title",
    "Book-Author": "Book_Author",
    "Year-Of-Publication": "First_Publish_Year",
}

df_renamed_1 = data1_colsrem.rename(columns=newcol_data1)

# %%
df_renamed_1.head()
# Out:
#           ISBN                                         Book_Title  \
# 0  "0195153448                                Classical Mythology
# 1  "0002005018                                       Clara Callan
# 2  "0060973129                               Decision in Normandy
# 3  "0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  "0393045218                             The Mummies of Urumchi
#
#             Book_Author  First_Publish_Year                   Publisher
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company

# %%
df_renamed_1["ISBN"] = df_renamed_1["ISBN"].astype(str).str.replace('"', '')

# %%
df_renamed_1.head()
# Out:
#          ISBN                                         Book_Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book_Author  First_Publish_Year                   Publisher
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company

# %%
df_renamed_1.dtypes
# Out:
# ISBN                  object
# Book_Title            object
# Book_Author           object
# First_Publish_Year     int64
# Publisher             object
# dtype: object

# %%
df_renamed_1.shape
# Out:
# (271379, 5)

# %%
null_values1 = df_renamed_1.isnull().sum()
null_values1
# Out:
# ISBN                  0
# Book_Title            0
# Book_Author           1
# First_Publish_Year    0
# Publisher             2
# dtype: int64

# %%
df_cleaned1 =  df_renamed_1.dropna()

# %%
df_cleaned1.shape
# Out:
# (271376, 5)

# %%
df_cleaned1.dtypes
# Out:
# ISBN                  object
# Book_Title            object
# Book_Author           object
# First_Publish_Year     int64
# Publisher             object
# dtype: object

# %%
df_cleaned1.head()
# Out:
#          ISBN                                         Book_Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book_Author  First_Publish_Year                   Publisher
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company

# %%
ISBN_list = df_cleaned1["ISBN"].tolist()
publisher_list = df_cleaned1["Publisher"].tolist()

# %%
df_cleaned1.head()
# Out:
#          ISBN                                         Book_Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book_Author  First_Publish_Year                   Publisher
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company

# %%
data2 = pd.read_csv('BX-Book-Ratings.csv', sep='\";\"', names=["User-ID", "ISBN", "Book-Rating"], encoding="latin1", skiprows=1, engine="python", quotechar='"')

# %%
data2.head()
# Out:
#    User-ID        ISBN Book-Rating
# 0  "276725  034545104X          0"
# 1  "276726  0155061224          5"
# 2  "276727  0446520802          0"
# 3  "276729  052165615X          3"
# 4  "276729  0521795028          6"

# %%
data2.dtypes
# Out:
# User-ID        object
# ISBN           object
# Book-Rating    object
# dtype: object

# %%
data2_colsrem = data2.drop(columns=['User-ID'])

# %%
data2_colsrem.head()
# Out:
#          ISBN Book-Rating
# 0  034545104X          0"
# 1  0155061224          5"
# 2  0446520802          0"
# 3  052165615X          3"
# 4  0521795028          6"

# %%
newcol_data2 = {
    "Book-Rating": "Book_Rating",
}

df_renamed_2 = data2_colsrem.rename(columns=newcol_data2)

# %%
df_renamed_2.head()
# Out:
#          ISBN Book_Rating
# 0  034545104X          0"
# 1  0155061224          5"
# 2  0446520802          0"
# 3  052165615X          3"
# 4  0521795028          6"

# %%
df_renamed_2["Book_Rating"] = df_renamed_2["Book_Rating"].astype(str).str.replace('"', '')

# %%
df_renamed_2.head()
# Out:
#          ISBN Book_Rating
# 0  034545104X           0
# 1  0155061224           5
# 2  0446520802           0
# 3  052165615X           3
# 4  0521795028           6

# %%
df_renamed_2.dtypes
# Out:
# ISBN           object
# Book_Rating    object
# dtype: object

# %%
df_renamed_2.shape
# Out:
# (1149780, 2)

# %%
null_values1 = df_renamed_2.isnull().sum()
null_values1
# Out:
# ISBN           0
# Book_Rating    0
# dtype: int64

# %%
df_renamed_2["Book_Rating"] = df_renamed_2["Book_Rating"].astype(int)

# %%
df_cleaned2 = df_renamed_2

# %%
df_cleaned2.dtypes
# Out:
# ISBN           object
# Book_Rating     int64
# dtype: object

# %%
df_cleaned2.head()
# Out:
#          ISBN  Book_Rating
# 0  034545104X            0
# 1  0155061224            5
# 2  0446520802            0
# 3  052165615X            3
# 4  0521795028            6

# %%
data3 = pd.read_csv('BOOK_DETAILS.csv')

# %%
data3.head()
# Out:
#          ISBN             Book_Title       Book_Author  Year-Of-Publication  \
# 0  3453064038        Incubus. Roman.      Colin Forbes                 1993
# 1  9136666690            A Cold Case    Cynthia Borris                 2007
# 2  9510236756    Minun sukuni tarina        Jari Tervo                 1999
# 3  1986505573  Whisper to Me of Love      Nicci French                 2023
# 4  4037883484     A Walk to Remember  Jurt W. Donsbach                 1944
#
#    Edition_Count  Book_Age Edition_Count_Category  Total_Reviews  No_of_Pages  \
# 0              1        32                    Low              0          437
# 1             42        18                   High            513          907
# 2              1        26                    Low            225          191
# 3             27         1                   High              7          521
# 4              8        81                 Medium            196          277
#
# ...

# %%
data3.dtypes
# Out:
# ISBN                       object
# Book_Title                 object
# Book_Author                object
# Year-Of-Publication         int64
# Edition_Count               int64
# Book_Age                    int64
# Edition_Count_Category     object
# Total_Reviews               int64
# No_of_Pages                 int64
# Book_Length_Category       object
# Popularity_Score          float64
# Book_Price                float64
# Bestseller                 object
# dtype: object

# %%
newcol_data3 = {
     "Year-Of-Publication": "First_Publish_Year",
}

df_renamed_3 = data3.rename(columns=newcol_data3)

# %%
df_renamed_3.dtypes
# Out:
# ISBN                       object
# Book_Title                 object
# Book_Author                object
# First_Publish_Year          int64
# Edition_Count               int64
# Book_Age                    int64
# Edition_Count_Category     object
# Total_Reviews               int64
# No_of_Pages                 int64
# Book_Length_Category       object
# Popularity_Score          float64
# Book_Price                float64
# Bestseller                 object
# dtype: object

# %%
df_renamed_3.head()
# Out:
#          ISBN             Book_Title       Book_Author  First_Publish_Year  \
# 0  3453064038        Incubus. Roman.      Colin Forbes                1993
# 1  9136666690            A Cold Case    Cynthia Borris                2007
# 2  9510236756    Minun sukuni tarina        Jari Tervo                1999
# 3  1986505573  Whisper to Me of Love      Nicci French                2023
# 4  4037883484     A Walk to Remember  Jurt W. Donsbach                1944
#
#    Edition_Count  Book_Age Edition_Count_Category  Total_Reviews  No_of_Pages  \
# 0              1        32                    Low              0          437
# 1             42        18                   High            513          907
# 2              1        26                    Low            225          191
# 3             27         1                   High              7          521
# 4              8        81                 Medium            196          277
#
# ...

# %%
df_renamed_3.shape
# Out:
# (4002, 13)

# %%
null_values3 = df_renamed_3.isnull().sum()
null_values3
# Out:
# ISBN                      0
# Book_Title                0
# Book_Author               0
# First_Publish_Year        0
# Edition_Count             0
# Book_Age                  0
# Edition_Count_Category    0
# Total_Reviews             0
# No_of_Pages               0
# Book_Length_Category      0
# Popularity_Score          0
# Book_Price                0
# Bestseller                0
# dtype: int64

# %%
df_renamed_3.dtypes
# Out:
# ISBN                       object
# Book_Title                 object
# Book_Author                object
# First_Publish_Year          int64
# Edition_Count               int64
# Book_Age                    int64
# Edition_Count_Category     object
# Total_Reviews               int64
# No_of_Pages                 int64
# Book_Length_Category       object
# Popularity_Score          float64
# Book_Price                float64
# Bestseller                 object
# dtype: object

# %%
df_renamed_3['Bestseller'] = df_renamed_3['Bestseller'].map({'Yes': 1, 'No': 0})

# %%
df_renamed_3.dtypes
# Out:
# ISBN                       object
# Book_Title                 object
# Book_Author                object
# First_Publish_Year          int64
# Edition_Count               int64
# Book_Age                    int64
# Edition_Count_Category     object
# Total_Reviews               int64
# No_of_Pages                 int64
# Book_Length_Category       object
# Popularity_Score          float64
# Book_Price                float64
# Bestseller                  int64
# dtype: object

# %%
df_cleaned3 = df_renamed_3

# %%
df_cleaned3.head()
# Out:
#          ISBN             Book_Title       Book_Author  First_Publish_Year  \
# 0  3453064038        Incubus. Roman.      Colin Forbes                1993
# 1  9136666690            A Cold Case    Cynthia Borris                2007
# 2  9510236756    Minun sukuni tarina        Jari Tervo                1999
# 3  1986505573  Whisper to Me of Love      Nicci French                2023
# 4  4037883484     A Walk to Remember  Jurt W. Donsbach                1944
#
#    Edition_Count  Book_Age Edition_Count_Category  Total_Reviews  No_of_Pages  \
# 0              1        32                    Low              0          437
# 1             42        18                   High            513          907
# 2              1        26                    Low            225          191
# 3             27         1                   High              7          521
# 4              8        81                 Medium            196          277
#
# ...

# %% [markdown]
# API DATA CLEANING

# %%
apidata = pd.read_csv('Combined_API_data.csv')

# %%
apidata.head()
# Out:
#                                                Title  \
# 0                                Classical Mythology
# 1                                       Clara Callan
# 2                               Decision in Normandy
# 3  Flu: The Story of the Great Influenza Pandemic...
# 4                             The Mummies of Urumchi
#
#                                       Author Subjects  First Publish Year  \
# 0                         Harris, Stephen L.      NaN              1995.0
# 1                          Richard B. Wright      NaN              2002.0
# 2                               Carlo D'Este      NaN              1983.0
# 3                                Gina Kolata      NaN              1999.0
# 4  E. J. W. Barber, Elizabeth Wayland Barber      NaN              1999.0
#
#    Edition Count  ISBN
# 0            4.0   NaN
# 1           11.0   NaN
# 2           18.0   NaN
# 3            9.0   NaN
# 4            4.0   NaN

# %%
apidata_colsrem = apidata.drop(columns=['Subjects', 'ISBN'])

# %%
apidata_colsrem.head()
# Out:
#                                                Title  \
# 0                                Classical Mythology
# 1                                       Clara Callan
# 2                               Decision in Normandy
# 3  Flu: The Story of the Great Influenza Pandemic...
# 4                             The Mummies of Urumchi
#
#                                       Author  First Publish Year  \
# 0                         Harris, Stephen L.              1995.0
# 1                          Richard B. Wright              2002.0
# 2                               Carlo D'Este              1983.0
# 3                                Gina Kolata              1999.0
# 4  E. J. W. Barber, Elizabeth Wayland Barber              1999.0
#
#    Edition Count
# 0            4.0
# 1           11.0
# 2           18.0
# 3            9.0
# 4            4.0

# %%
newcol_apidata = {
    "Title": "Book_Title",
    "Author": "Book_Author",
    "First Publish Year": "First_Publish_Year",
    "Edition Count": "Edition_Count",
}

df_renamed_api = apidata_colsrem.rename(columns=newcol_apidata)

# %%
df_renamed_api.head()
# Out:
#                                           Book_Title  \
# 0                                Classical Mythology
# 1                                       Clara Callan
# 2                               Decision in Normandy
# 3  Flu: The Story of the Great Influenza Pandemic...
# 4                             The Mummies of Urumchi
#
#                                  Book_Author  First_Publish_Year  \
# 0                         Harris, Stephen L.              1995.0
# 1                          Richard B. Wright              2002.0
# 2                               Carlo D'Este              1983.0
# 3                                Gina Kolata              1999.0
# 4  E. J. W. Barber, Elizabeth Wayland Barber              1999.0
#
#    Edition_Count
# 0            4.0
# 1           11.0
# 2           18.0
# 3            9.0
# 4            4.0

# %%
df_renamed_api.shape
# Out:
# (10000, 4)

# %%
null_values = df_renamed_api.isnull().sum()
null_values
# Out:
# Book_Title               0
# Book_Author              1
# First_Publish_Year    4139
# Edition_Count         3921
# dtype: int64

# %%
df_cleaned4 =  df_renamed_api.dropna()

# %%
df_cleaned4.isnull().sum()
# Out:
# Book_Title            0
# Book_Author           0
# First_Publish_Year    0
# Edition_Count         0
# dtype: int64

# %%
df_cleaned4.shape
# Out:
# (5860, 4)

# %%
df_cleaned4.dtypes
# Out:
# Book_Title             object
# Book_Author            object
# First_Publish_Year    float64
# Edition_Count         float64
# dtype: object

# %%
df_cleaned4["First_Publish_Year"] = df_cleaned4["First_Publish_Year"].astype("int64") 
df_cleaned4["Edition_Count"] = df_cleaned4["Edition_Count"].astype("int64")
# Out:
# /tmp/ipykernel_184/4061148692.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned4["First_Publish_Year"] = df_cleaned4["First_Publish_Year"].astype("int64")
# /tmp/ipykernel_184/4061148692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned4["Edition_Count"] = df_cleaned4["Edition_Count"].astype("int64")

# %%
df_cleaned4.dtypes
# Out:
# Book_Title            object
# Book_Author           object
# First_Publish_Year     int64
# Edition_Count          int64
# dtype: object

# %%
df_cleaned4.head()
# Out:
#                                           Book_Title  \
# 0                                Classical Mythology
# 1                                       Clara Callan
# 2                               Decision in Normandy
# 3  Flu: The Story of the Great Influenza Pandemic...
# 4                             The Mummies of Urumchi
#
#                                  Book_Author  First_Publish_Year  \
# 0                         Harris, Stephen L.                1995
# 1                          Richard B. Wright                2002
# 2                               Carlo D'Este                1983
# 3                                Gina Kolata                1999
# 4  E. J. W. Barber, Elizabeth Wayland Barber                1999
#
#    Edition_Count
# 0              4
# 1             11
# 2             18
# 3              9
# 4              4

# %%
df =  pd.merge(df_cleaned1, df_cleaned2, on="ISBN", how="inner")

# %%
df.head()
# Out:
#          ISBN           Book_Title           Book_Author  First_Publish_Year  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
# 2  0002005018         Clara Callan  Richard Bruce Wright                2001
# 3  0002005018         Clara Callan  Richard Bruce Wright                2001
# 4  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher  Book_Rating
# 0  Oxford University Press            0
# 1    HarperFlamingo Canada            5
# 2    HarperFlamingo Canada            0
# 3    HarperFlamingo Canada            8
# 4    HarperFlamingo Canada            0

# %%
df.shape
# Out:
# (1031172, 6)

# %%
duplicate_count = df.duplicated().sum()
print("Total duplicated rows:", duplicate_count)
# Out:
# Total duplicated rows: 587397

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (443775, 6)

# %%
df.head()
# Out:
#          ISBN           Book_Title           Book_Author  First_Publish_Year  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
# 2  0002005018         Clara Callan  Richard Bruce Wright                2001
# 3  0002005018         Clara Callan  Richard Bruce Wright                2001
# 8  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher  Book_Rating
# 0  Oxford University Press            0
# 1    HarperFlamingo Canada            5
# 2    HarperFlamingo Canada            0
# 3    HarperFlamingo Canada            8
# 8    HarperFlamingo Canada            9

# %%
df_unique = df.drop_duplicates(subset=['ISBN'], keep='first')
df_unique.to_csv("df_data.csv", index=False)

# %%
df1 = pd.read_csv('df_data.csv')

# %%
df1.head()
# Out:
#          ISBN                                         Book_Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book_Author  First_Publish_Year                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#    Book_Rating
# 0            0
# 1            5
# 2            0
# 3            0
# 4            0

# %%
df1.shape
# Out:
# (270167, 6)

# %%
duplicate_count = df.duplicated().sum()
print("Total duplicated rows:", duplicate_count)
# Out:
# Total duplicated rows: 0

# %%
df3 =  pd.merge(df1, df_cleaned3, on="ISBN", how="inner")

# %%
df3.head()
# Out:
#          ISBN                   Book_Title_x         Book_Author_x  \
# 0  0399135782         The Kitchen God's Wife               Amy Tan
# 1  0399135782         The Kitchen God's Wife               Amy Tan
# 2  0671870432                PLEADING GUILTY           Scott Turow
# 3  0771074670    Nights Below Station Street  David Adams Richards
# 4  1881320189  Goodbye to the Buttermilk Sky          Julia Oliver
#
#    First_Publish_Year_x         Publisher  Book_Rating  \
# 0                  1991  Putnam Pub Group            0
# 1                  1991  Putnam Pub Group            0
# 2                  1993        Audioworks            0
# 3                  1988   Emblem Editions            0
# 4                  1994    River City Pub            7
#
#                     Book_Title_y         Book_Author_y  First_Publish_Year_y  \
# 0         The Kitchen God's Wife               Amy Tan                  1991
# ...

# %%
df3.shape
# Out:
# (2679, 18)

# %%
df3_ = df3.drop(columns=['Book_Title_x', 'Book_Author_x','First_Publish_Year_x'])

# %%
df3_.head()
# Out:
#          ISBN         Publisher  Book_Rating                   Book_Title_y  \
# 0  0399135782  Putnam Pub Group            0         The Kitchen God's Wife
# 1  0399135782  Putnam Pub Group            0         The Kitchen God's Wife
# 2  0671870432        Audioworks            0                PLEADING GUILTY
# 3  0771074670   Emblem Editions            0    Nights Below Station Street
# 4  1881320189    River City Pub            7  Goodbye to the Buttermilk Sky
#
#           Book_Author_y  First_Publish_Year_y  Edition_Count  Book_Age  \
# 0               Amy Tan                  1991             48        35
# 1               Amy Tan                  1991             46        34
# 2           Scott Turow                  1993             21        32
# 3  David Adams Richards                  1988              5        37
# 4          Julia Oliver                  1994              1        33
#
#   Edition_Count_Category  Total_Reviews  No_of_Pages Book_Length_Category  \
# ...

# %%
df3_.shape
# Out:
# (2679, 15)

# %%
newcol_f1data = {
    "Book_Title_y": "Book_Title",
    "Book_Author_y": "Book_Author",
    "First_Publish_Year_y": "First_Publish_Year",
}

df_renamed_df3 = df3_.rename(columns=newcol_f1data)

# %%
df_renamed_df3.head()
# Out:
#          ISBN         Publisher  Book_Rating                     Book_Title  \
# 0  0399135782  Putnam Pub Group            0         The Kitchen God's Wife
# 1  0399135782  Putnam Pub Group            0         The Kitchen God's Wife
# 2  0671870432        Audioworks            0                PLEADING GUILTY
# 3  0771074670   Emblem Editions            0    Nights Below Station Street
# 4  1881320189    River City Pub            7  Goodbye to the Buttermilk Sky
#
#             Book_Author  First_Publish_Year  Edition_Count  Book_Age  \
# 0               Amy Tan                1991             48        35
# 1               Amy Tan                1991             46        34
# 2           Scott Turow                1993             21        32
# 3  David Adams Richards                1988              5        37
# 4          Julia Oliver                1994              1        33
#
#   Edition_Count_Category  Total_Reviews  No_of_Pages Book_Length_Category  \
# ...

# %%
duplicate_count = df3.duplicated().sum()
print("Total duplicated rows:", duplicate_count)
# Out:
# Total duplicated rows: 0

# %%
Final = pd.merge(df_renamed_df3, df_cleaned4, on=["Book_Title", "Book_Author", "First_Publish_Year"], how="inner")

# %%
Final.head()
# Out:
#          ISBN         Publisher  Book_Rating                   Book_Title  \
# 0  0399135782  Putnam Pub Group            0       The Kitchen God's Wife
# 1  0399135782  Putnam Pub Group            0       The Kitchen God's Wife
# 2  1558002669  Audio Literature            0       The Kitchen God's Wife
# 3  0671870432        Audioworks            0              PLEADING GUILTY
# 4  0771074670   Emblem Editions            0  Nights Below Station Street
#
#             Book_Author  First_Publish_Year  Edition_Count_x  Book_Age  \
# 0               Amy Tan                1991               48        35
# 1               Amy Tan                1991               46        34
# 2               Amy Tan                1991               46        34
# 3           Scott Turow                1993               21        32
# 4  David Adams Richards                1988                5        37
#
#   Edition_Count_Category  Total_Reviews  No_of_Pages Book_Length_Category  \
# ...

# %%
newcol_finaldata = {
    "Edition_Count_x": "Edition_Count",
}

df_renamed_Final = Final.rename(columns=newcol_finaldata)

# %%
Final_ = df_renamed_Final.drop(columns=['Edition_Count_y'])

# %%
Final_.head()
# Out:
#          ISBN         Publisher  Book_Rating                   Book_Title  \
# 0  0399135782  Putnam Pub Group            0       The Kitchen God's Wife
# 1  0399135782  Putnam Pub Group            0       The Kitchen God's Wife
# 2  1558002669  Audio Literature            0       The Kitchen God's Wife
# 3  0671870432        Audioworks            0              PLEADING GUILTY
# 4  0771074670   Emblem Editions            0  Nights Below Station Street
#
#             Book_Author  First_Publish_Year  Edition_Count  Book_Age  \
# 0               Amy Tan                1991             48        35
# 1               Amy Tan                1991             46        34
# 2               Amy Tan                1991             46        34
# 3           Scott Turow                1993             21        32
# 4  David Adams Richards                1988              5        37
#
#   Edition_Count_Category  Total_Reviews  No_of_Pages Book_Length_Category  \
# ...

# %%
Final_.shape
# Out:
# (2679, 15)

# %%
df_unique1 = Final_.drop_duplicates(subset=['ISBN'], keep='first')
df_unique1.to_csv("Final_data.csv", index=False)

# %%
combined = pd.read_csv('Final_data.csv')

# %%
combined.shape
# Out:
# (2002, 15)

# %%
combined.head()
# Out:
#          ISBN         Publisher  Book_Rating                     Book_Title  \
# 0  0399135782  Putnam Pub Group            0         The Kitchen God's Wife
# 1  1558002669  Audio Literature            0         The Kitchen God's Wife
# 2  0671870432        Audioworks            0                PLEADING GUILTY
# 3  0771074670   Emblem Editions            0    Nights Below Station Street
# 4  1881320189    River City Pub            7  Goodbye to the Buttermilk Sky
#
#             Book_Author  First_Publish_Year  Edition_Count  Book_Age  \
# 0               Amy Tan                1991             48        35
# 1               Amy Tan                1991             46        34
# 2           Scott Turow                1993             21        32
# 3  David Adams Richards                1988              5        37
# 4          Julia Oliver                1994              1        33
#
#   Edition_Count_Category  Total_Reviews  No_of_Pages Book_Length_Category  \
# ...

# %%
combined.dtypes
# Out:
# ISBN                       object
# Publisher                  object
# Book_Rating                 int64
# Book_Title                 object
# Book_Author                object
# First_Publish_Year          int64
# Edition_Count               int64
# Book_Age                    int64
# Edition_Count_Category     object
# Total_Reviews               int64
# No_of_Pages                 int64
# Book_Length_Category       object
# Popularity_Score          float64
# Book_Price                float64
# Bestseller                  int64
# dtype: object

# %%
duplicate_count = combined.duplicated().sum()
print("Total duplicated rows:", duplicate_count)
# Out:
# Total duplicated rows: 0

# %%
final_colsrem = combined.drop(columns=['Book_Rating'])

# %%
final_colsrem.shape
# Out:
# (2002, 14)

# %%
final_colsrem.head()
# Out:
#          ISBN         Publisher                     Book_Title  \
# 0  0399135782  Putnam Pub Group         The Kitchen God's Wife
# 1  1558002669  Audio Literature         The Kitchen God's Wife
# 2  0671870432        Audioworks                PLEADING GUILTY
# 3  0771074670   Emblem Editions    Nights Below Station Street
# 4  1881320189    River City Pub  Goodbye to the Buttermilk Sky
#
#             Book_Author  First_Publish_Year  Edition_Count  Book_Age  \
# 0               Amy Tan                1991             48        35
# 1               Amy Tan                1991             46        34
# 2           Scott Turow                1993             21        32
# 3  David Adams Richards                1988              5        37
# 4          Julia Oliver                1994              1        33
#
#   Edition_Count_Category  Total_Reviews  No_of_Pages Book_Length_Category  \
# 0                   High              0          290               Medium
# ...

# %%
final_filtered =  final_colsrem[final_colsrem['Total_Reviews'] != 0]

# %%
final_filtered.shape
# Out:
# (1009, 14)

# %%
final_filtered.head()
# Out:
#           ISBN           Publisher                     Book_Title  \
# 4   1881320189      River City Pub  Goodbye to the Buttermilk Sky
# 8   0440295734        Bantam Books                  The Testament
# 9   0553502271  Random House Audio                  The Testament
# 10  0439095026          Scholastic   Tell Me This Isn't Happening
# 14  0060168013       Harpercollins                 Pigs in Heaven
#
#            Book_Author  First_Publish_Year  Edition_Count  Book_Age  \
# 4         Julia Oliver                1994              1        33
# 8         John Grisham                1999             62        26
# 9         John Grisham                1999             61        26
# 10     Robynn Clairday                1999              1        26
# 14  Barbara Kingsolver                1993             13        32
#
#    Edition_Count_Category  Total_Reviews  No_of_Pages Book_Length_Category  \
# 4                     Low            189          363               Medium
# ...

# %%
final_filtered.to_csv("Final_cleaned_data.csv", index=False)
